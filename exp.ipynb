# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('sensor.csv')
data.head(3)
# Out:
#    Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# 0           0  2018-04-01 00:00:00   2.465394   47.09201    53.2118
# 1           1  2018-04-01 00:01:00   2.465394   47.09201    53.2118
# 2           2  2018-04-01 00:02:00   2.444734   47.35243    53.2118
#
#    sensor_03  sensor_04  sensor_05  sensor_06  sensor_07  ...  sensor_43  \
# 0   46.31076   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 1   46.31076   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 2   46.39757   638.8889   73.54598   13.32465   16.03733  ...   41.66666
#
#    sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  sensor_49  \
# 0  39.641200   65.68287   50.92593  38.194440   157.9861   67.70834
# 1  39.641200   65.68287   50.92593  38.194440   157.9861   67.70834
# 2  39.351852   65.39352   51.21528  38.194443   155.9606   67.12963
#
#    sensor_50  sensor_51  machine_status
# 0   243.0556   201.3889          NORMAL
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220320 entries, 0 to 220319
# Data columns (total 55 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      220320 non-null  int64
#  1   timestamp       220320 non-null  object
#  2   sensor_00       210112 non-null  float64
#  3   sensor_01       219951 non-null  float64
#  4   sensor_02       220301 non-null  float64
#  5   sensor_03       220301 non-null  float64
#  6   sensor_04       220301 non-null  float64
#  7   sensor_05       220301 non-null  float64
#  8   sensor_06       215522 non-null  float64
#  9   sensor_07       214869 non-null  float64
#  10  sensor_08       215213 non-null  float64
#  11  sensor_09       215725 non-null  float64
#  12  sensor_10       220301 non-null  float64
#  13  sensor_11       220301 non-null  float64
#  14  sensor_12       220301 non-null  float64
#  15  sensor_13       220301 non-null  float64
# ...

# %%
data.describe()
# Out:
#           Unnamed: 0      sensor_00      sensor_01      sensor_02  \
# count  220320.000000  210112.000000  219951.000000  220301.000000
# mean   110159.500000       2.372221      47.591611      50.867392
# std     63601.049991       0.412227       3.296666       3.666820
# min         0.000000       0.000000       0.000000      33.159720
# 25%     55079.750000       2.438831      46.310760      50.390620
# 50%    110159.500000       2.456539      48.133678      51.649300
# 75%    165239.250000       2.499826      49.479160      52.777770
# max    220319.000000       2.549016      56.727430      56.032990
#
#            sensor_03      sensor_04      sensor_05      sensor_06  \
# count  220301.000000  220301.000000  220301.000000  215522.000000
# mean       43.752481     590.673936      73.396414      13.501537
# std         2.418887     144.023912      17.298247       2.163736
# min        31.640620       2.798032       0.000000       0.014468
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0             0
# timestamp              0
# sensor_00          10208
# sensor_01            369
# sensor_02             19
# sensor_03             19
# sensor_04             19
# sensor_05             19
# sensor_06           4798
# sensor_07           5451
# sensor_08           5107
# sensor_09           4595
# sensor_10             19
# sensor_11             19
# sensor_12             19
# sensor_13             19
# sensor_14             21
# sensor_15         220320
# sensor_16             31
# sensor_17             46
# sensor_18             46
# sensor_19             16
# sensor_20             16
# sensor_21             16
# sensor_22             41
# sensor_23             16
# sensor_24             16
# sensor_25             36
# sensor_26             20
# sensor_27             16
# sensor_28             16
# sensor_29             72
# sensor_30            261
# sensor_31             16
# sensor_32             68
# sensor_33             16
# sensor_34             16
# ...

# %%
data=data.drop(['Unnamed: 0','sensor_15','sensor_51','sensor_50','sensor_15'],axis=1)

# %%
data['timestamp']=pd.to_datetime(data['timestamp'])
data['month']=data['timestamp'].dt.month
data['day']=data['timestamp'].dt.day
data['hour']=data['timestamp'].dt.hour
data['minute']=data['timestamp'].dt.minute

# %%
data=data.drop(['timestamp'],axis=1)

# %%
data
# Out:
#         sensor_00  sensor_01  sensor_02  sensor_03   sensor_04  sensor_05  \
# 0        2.465394   47.09201  53.211800  46.310760  634.375000   76.45975
# 1        2.465394   47.09201  53.211800  46.310760  634.375000   76.45975
# 2        2.444734   47.35243  53.211800  46.397570  638.888900   73.54598
# 3        2.460474   47.09201  53.168400  46.397568  628.125000   76.98898
# 4        2.445718   47.13541  53.211800  46.397568  636.458300   76.58897
# ...           ...        ...        ...        ...         ...        ...
# 220315   2.407350   47.69965  50.520830  43.142361  634.722229   64.59095
# 220316   2.400463   47.69965  50.564240  43.142361  630.902771   65.83363
# 220317   2.396528   47.69965  50.520830  43.142361  625.925903   67.29445
# 220318   2.406366   47.69965  50.520832  43.142361  635.648100   65.09175
# 220319   2.396528   47.69965  50.520832  43.142361  639.814800   65.45634
#
#         sensor_06  sensor_07  sensor_08  sensor_09  ...  sensor_45  sensor_46  \
# ...

# %%
data['machine_status'].unique()
# Out:
# array(['NORMAL', 'BROKEN', 'RECOVERING'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
data['machine_status'] = encoder.fit_transform(data['machine_status'])
data['machine_status'].unique()
# Out:
# array([1, 0, 2])

# %%
data.fillna(data.median(), inplace=True)

# %%
X = data.drop(columns=['machine_status'])
y = data['machine_status']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_scaled =scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.3,random_state=42)

# %%
import lightgbm as lgb
model = lgb.LGBMClassifier(objective='multiclass',num_class=len(encoder.classes_), n_estimators=100,random_state=42,n_jobs=-1)

# %%
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.021047 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12318
# [LightGBM] [Info] Number of data points in the train set: 154224, number of used features: 53
# [LightGBM] [Info] Start training from score -10.336723
# [LightGBM] [Info] Start training from score -0.068371
# [LightGBM] [Info] Start training from score -2.717294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
from sklearn.metrics import classification_report, roc_auc_score,confusion_matrix
print(classification_report(y_test, y_pred))
print(f"ROC-AUC: {roc_auc_score(y_test, model.predict_proba(X_test), multi_class='ovr')}")
# Out:
# c:\Users\kk061\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\kk061\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\kk061\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
importance = model.feature_importances_
features = X.columns

# %%
feature_importance_df = pd.DataFrame({'Feature': features, 'Importance': importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
feature_importance_df
# Out:
#       Feature  Importance
# 0   sensor_00         379
# 4   sensor_04         375
# 1   sensor_01         358
# 45  sensor_46         253
# 2   sensor_02         249
# 10  sensor_10         235
# 47  sensor_48         220
# 48  sensor_49         202
# 5   sensor_05         199
# 44  sensor_45         193
# 28  sensor_29         190
# 52     minute         181
# 13  sensor_13         165
# 11  sensor_11         163
# 30  sensor_31         160
# 25  sensor_26         157
# 34  sensor_35         157
# 37  sensor_38         149
# 26  sensor_27         147
# 6   sensor_06         147
# 43  sensor_44         145
# 33  sensor_34         141
# 3   sensor_03         141
# 38  sensor_39         138
# 27  sensor_28         130
# 31  sensor_32         126
# 51       hour         125
# 14  sensor_14         125
# 8   sensor_08         121
# 12  sensor_12         121
# 42  sensor_43         120
# 32  sensor_33         117
# 35  sensor_36         116
# 46  sensor_47         110
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.title('Feature Importance')
plt.show()

# %%
import seaborn as sns
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
fpr = dict()
tpr = dict()
roc_auc = dict()
y_prob = model.predict_proba(X_test)

for i in range(len(encoder.classes_)):
    fpr[i], tpr[i], _ = roc_curve(y_test == i, y_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(10, 6))
colors = ['blue', 'green', 'red'] 
for i in range(len(encoder.classes_)):
    plt.plot(fpr[i], tpr[i], color=colors[i], lw=2, label=f'Class {encoder.classes_[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
